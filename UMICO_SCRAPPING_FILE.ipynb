# %% [markdown]
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0">![](data:image/svg+xml;base64,...)</span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0"></span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0">![](data:image/svg+xml;base64,...)</span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0">![](data:image/svg+xml;base64,...)</span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0">![](data:image/svg+xml;base64,...)</span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0"></span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0"></span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0">![](data:image/svg+xml;base64,...)</span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0"></span>
#
# -CodeMarkdownRaw<span class="f1ozlkqi"></span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0">![](data:image/svg+xml;base64,...)</span><span class="jp-ToolbarButtonComponent-label">JupyterLab</span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0">![](data:image/svg+xml;base64,...)</span>
#
# <span class="jp-ToolbarButtonComponent-label">Python 3
# (ipykernel)</span>
#
#
#
# Kernel status: Idle
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0">![](data:image/svg+xml;base64,...)</span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0">![](data:image/svg+xml;base64,...)</span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0">![](data:image/svg+xml;base64,...)</span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0">![](data:image/svg+xml;base64,...)</span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0">![](data:image/svg+xml;base64,...)</span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0">![](data:image/svg+xml;base64,...)</span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0">![](data:image/svg+xml;base64,...)</span>
#
# <span class="jp-ToolbarButtonComponent-icon f1vya9e0">![](data:image/svg+xml;base64,...)</span>
#
# \[3\]:
#
# <span class="ͼs">import</span> re
#
# <span class="ͼs">import</span> time
#
# <span class="ͼs">import</span> requests
#
# <span class="ͼs">import</span> tqdm
#
# <span class="ͼs">import</span> pandas <span class="ͼs">as</span> pd
#
# <span class="ͼs">from</span> bs4 <span class="ͼs">import</span>
# BeautifulSoup
#
# \[67\]:
#
# all_urls <span class="ͼ10">=</span>
# <span class="ͼ14">\[</span><span class="ͼ14">\]</span>
#
#
#
# <span class="ͼs">for</span> i <span class="ͼs">in</span>
# tqdm<span class="ͼ19">.</span><span class="ͼz">tqdm</span><span class="ͼ19">(</span>range<span class="ͼ19">(</span><span class="ͼu">1</span><span class="ͼ19">,</span>
# <span class="ͼu">12</span><span class="ͼ19">)</span><span class="ͼ19">)</span>:
#
# url <span class="ͼ10">=</span>
# <span class="ͼ13">f"https://umico.az/categories/800-ushaq-qidasi?page=</span><span class="ͼ14">{</span>i<span class="ͼ14">}</span><span class="ͼ13">"</span>
#
# headers <span class="ͼ10">=</span> <span class="ͼ14">{</span>
#
# <span class="ͼ12">"User-Agent"</span>: <span class="ͼ12">"Mozilla/5.0
# (X11; Ubuntu; Linux x86_64; rv:109.0) Gecko/20100101
# Firefox/117.0"</span>
#
# <span class="ͼ14">}</span>
#
# response <span class="ͼ10">=</span>
# requests<span class="ͼ19">.</span><span class="ͼz">get</span><span class="ͼ19">(</span>url<span class="ͼ19">,</span>
# headers<span class="ͼ10">=</span>headers<span class="ͼ19">)</span>
#
# bs <span class="ͼ10">=</span>
# BeautifulSoup<span class="ͼ19">(</span>response<span class="ͼ19">.</span><span class="ͼz">content</span><span class="ͼ19">,</span>
# <span class="ͼ12">'html.parser'</span><span class="ͼ19">)</span>
#
# urls_for_pages <span class="ͼ10">=</span>
# <span class="ͼ14">\[</span><span class="ͼ12">'https://umico.az/'</span>
# <span class="ͼ10">+</span>
# url<span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'a'</span><span class="ͼ19">)</span><span class="ͼ14">\[</span><span class="ͼ12">'href'</span><span class="ͼ14">\]</span>
# <span class="ͼs">for</span> url <span class="ͼs">in</span>
# bs<span class="ͼ19">.</span><span class="ͼz">find_all</span><span class="ͼ19">(</span><span class="ͼ12">'div'</span><span class="ͼ19">,</span>
# class\_<span class="ͼ10">=</span><span class="ͼ12">'MPProductItem'</span><span class="ͼ19">)</span><span class="ͼ14">\]</span>
#
# all_urls<span class="ͼ19">.</span><span class="ͼz">extend</span><span class="ͼ19">(</span>urls_for_pages<span class="ͼ19">)</span>
#
#
#
#     100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [00:09<00:00,  1.18it/s]
#
# \[75\]:
#
# len<span class="ͼ19">(</span>all_urls<span class="ͼ19">)</span>
#
# \[75\]:
#
#     249
#
# \[89\]:
#
# Title <span class="ͼ10">=</span>
# list<span class="ͼ19">(</span><span class="ͼ19">)</span>
#
# Rating <span class="ͼ10">=</span>
# list<span class="ͼ19">(</span><span class="ͼ19">)</span>
#
# Comment <span class="ͼ10">=</span>
# list<span class="ͼ19">(</span><span class="ͼ19">)</span>
#
# Product_Code <span class="ͼ10">=</span>
# list<span class="ͼ19">(</span><span class="ͼ19">)</span>
#
# Price <span class="ͼ10">=</span>
# list<span class="ͼ19">(</span><span class="ͼ19">)</span>
#
# Seller <span class="ͼ10">=</span>
# list<span class="ͼ19">(</span><span class="ͼ19">)</span>
#
# Image <span class="ͼ10">=</span>
# list<span class="ͼ19">(</span><span class="ͼ19">)</span>
#
#
#
# <span class="ͼs">for</span> url <span class="ͼs">in</span>
# tqdm<span class="ͼ19">.</span><span class="ͼz">tqdm</span><span class="ͼ19">(</span>all_urls<span class="ͼ19">)</span>:
#
# response <span class="ͼ10">=</span>
# requests<span class="ͼ19">.</span><span class="ͼz">get</span><span class="ͼ19">(</span>url<span class="ͼ19">,</span>
# headers<span class="ͼ10">=</span>headers<span class="ͼ19">)</span>
#
# bs <span class="ͼ10">=</span>
# BeautifulSoup<span class="ͼ19">(</span>response<span class="ͼ19">.</span><span class="ͼz">content</span><span class="ͼ19">,</span>
# <span class="ͼ12">'html.parser'</span><span class="ͼ19">)</span>
#
# non <span class="ͼ10">=</span> <span class="ͼ1d">True</span>
#
# count <span class="ͼ10">=</span> <span class="ͼu">0</span>
#
# <span class="ͼs">while</span> non:
#
# <span class="ͼs">if</span>
# bs<span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'h1'</span><span class="ͼ19">,</span>
# <span class="ͼ14">{</span><span class="ͼ12">'itemprop'</span>:
# <span class="ͼ12">'name'</span><span class="ͼ14">}</span><span class="ͼ19">)</span>
# <span class="ͼs">is</span> <span class="ͼs">None</span>:
#
# response <span class="ͼ10">=</span>
# requests<span class="ͼ19">.</span><span class="ͼz">get</span><span class="ͼ19">(</span>url<span class="ͼ19">,</span>
# headers<span class="ͼ10">=</span>headers<span class="ͼ19">)</span>
#
# bs <span class="ͼ10">=</span>
# BeautifulSoup<span class="ͼ19">(</span>response<span class="ͼ19">.</span><span class="ͼz">content</span><span class="ͼ19">,</span>
# <span class="ͼ12">'html.parser'</span><span class="ͼ19">)</span>
#
# time<span class="ͼ19">.</span><span class="ͼz">sleep</span><span class="ͼ19">(</span><span class="ͼu">1</span><span class="ͼ19">)</span>
#
# count <span class="ͼ10">+=</span> <span class="ͼu">1</span>
#
# <span class="ͼs">if</span> count <span class="ͼ10">==</span>
# <span class="ͼu">1</span>:
#
# <span class="ͼs">break</span>
#
# <span class="ͼs">else</span>:
#
# non <span class="ͼ10">=</span> <span class="ͼ1d">False</span>
#
#
#
# Title<span class="ͼ19">.</span><span class="ͼz">append</span><span class="ͼ19">(</span>bs<span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'h1'</span><span class="ͼ19">,</span>
# <span class="ͼ14">{</span><span class="ͼ12">'itemprop'</span>:
# <span class="ͼ12">'name'</span><span class="ͼ14">}</span><span class="ͼ19">)</span><span class="ͼ19">.</span><span class="ͼz">text</span>
# <span class="ͼs">if</span>
# bs<span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'h1'</span><span class="ͼ19">,</span>
# <span class="ͼ14">{</span><span class="ͼ12">'itemprop'</span>:
# <span class="ͼ12">'name'</span><span class="ͼ14">}</span><span class="ͼ19">)</span>
# <span class="ͼs">else</span>
# <span class="ͼs">None</span><span class="ͼ19">)</span>
#
# Rating<span class="ͼ19">.</span><span class="ͼz">append</span><span class="ͼ19">(</span>bs<span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'span'</span><span class="ͼ19">,</span>
# <span class="ͼ14">{</span><span class="ͼ12">'class'</span>:
# <span class="ͼ12">'Rating'</span><span class="ͼ14">}</span><span class="ͼ19">)</span><span class="ͼ19">.</span><span class="ͼz">text</span>
# <span class="ͼs">if</span>
# bs<span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'span'</span><span class="ͼ19">,</span>
# <span class="ͼ14">{</span><span class="ͼ12">'class'</span>:
# <span class="ͼ12">'Rating'</span><span class="ͼ14">}</span><span class="ͼ19">)</span>
# <span class="ͼs">else</span>
# <span class="ͼ12">'0'</span><span class="ͼ19">)</span>
#
# Comment<span class="ͼ19">.</span><span class="ͼz">append</span><span class="ͼ19">(</span>bs<span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'span'</span><span class="ͼ19">,</span>
# <span class="ͼ14">{</span><span class="ͼ12">'class'</span>:
# <span class="ͼ12">'Count'</span><span class="ͼ14">}</span><span class="ͼ19">)</span><span class="ͼ19">.</span><span class="ͼz">text</span>
# <span class="ͼs">if</span>
# bs<span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'span'</span><span class="ͼ19">,</span>
# <span class="ͼ14">{</span><span class="ͼ12">'class'</span>:
# <span class="ͼ12">'Count'</span><span class="ͼ14">}</span><span class="ͼ19">)</span>
# <span class="ͼs">else</span>
# <span class="ͼ12">''</span><span class="ͼ19">)</span>
#
# Product_Code<span class="ͼ19">.</span><span class="ͼz">append</span><span class="ͼ19">(</span>bs<span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'span'</span><span class="ͼ19">,</span>
# <span class="ͼ14">{</span><span class="ͼ12">'class'</span>:
# <span class="ͼ12">'MPProductMainDesc-ProductCode'</span><span class="ͼ14">}</span><span class="ͼ19">)</span><span class="ͼ19">.</span><span class="ͼz">text</span>
# <span class="ͼs">if</span>
# bs<span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'span'</span><span class="ͼ19">,</span>
# <span class="ͼ14">{</span><span class="ͼ12">'class'</span>:
# <span class="ͼ12">'MPProductMainDesc-ProductCode'</span><span class="ͼ14">}</span><span class="ͼ19">)</span>
# <span class="ͼs">else</span>
# <span class="ͼs">None</span><span class="ͼ19">)</span>
#
# Price<span class="ͼ19">.</span><span class="ͼz">append</span><span class="ͼ19">(</span>bs<span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'div'</span><span class="ͼ19">,</span>
# <span class="ͼ14">{</span><span class="ͼ12">'class'</span>:
# <span class="ͼ12">'MPProductMainDesc-OfferPrice'</span><span class="ͼ14">}</span><span class="ͼ19">)</span><span class="ͼ19">.</span><span class="ͼz">text</span>
# <span class="ͼs">if</span>
# bs<span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'div'</span><span class="ͼ19">,</span>
# <span class="ͼ14">{</span><span class="ͼ12">'class'</span>:
# <span class="ͼ12">'MPProductMainDesc-OfferPrice'</span><span class="ͼ14">}</span><span class="ͼ19">)</span>
# <span class="ͼs">else</span>
# <span class="ͼs">None</span><span class="ͼ19">)</span>
#
# Seller<span class="ͼ19">.</span><span class="ͼz">append</span><span class="ͼ19">(</span><span class="ͼ12">'\_\_\_'</span><span class="ͼ19">.</span><span class="ͼz">join</span><span class="ͼ19">(</span><span class="ͼ14">\[</span>i<span class="ͼ19">.</span><span class="ͼz">text</span>
# <span class="ͼs">for</span> i <span class="ͼs">in</span>
# bs<span class="ͼ19">.</span><span class="ͼz">find_all</span><span class="ͼ19">(</span><span class="ͼ12">'div'</span><span class="ͼ19">,</span>
# <span class="ͼ14">{</span><span class="ͼ12">'class'</span>:
# <span class="ͼ12">'mt-2'</span><span class="ͼ14">}</span><span class="ͼ19">)</span><span class="ͼ14">\]</span><span class="ͼ19">)</span>
# <span class="ͼs">if</span>
# bs<span class="ͼ19">.</span><span class="ͼz">find_all</span><span class="ͼ19">(</span><span class="ͼ12">'div'</span><span class="ͼ19">,</span>
# <span class="ͼ14">{</span><span class="ͼ12">'class'</span>:
# <span class="ͼ12">'mt-2'</span><span class="ͼ14">}</span><span class="ͼ19">)</span>
# <span class="ͼs">else</span>
# <span class="ͼs">None</span><span class="ͼ19">)</span>
#
# Image<span class="ͼ19">.</span><span class="ͼz">append</span><span class="ͼ19">(</span>bs<span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'div'</span><span class="ͼ19">,</span>
# <span class="ͼ14">{</span><span class="ͼ12">'class'</span>:
# <span class="ͼ12">'MPProductSlider-Main
# relative'</span><span class="ͼ14">}</span><span class="ͼ19">)</span><span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'img'</span><span class="ͼ19">)</span><span class="ͼ14">\[</span><span class="ͼ12">'src'</span><span class="ͼ14">\]</span>
# <span class="ͼs">if</span>
# bs<span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'div'</span><span class="ͼ19">,</span>
# <span class="ͼ14">{</span><span class="ͼ12">'class'</span>:
# <span class="ͼ12">'MPProductSlider-Main
# relative'</span><span class="ͼ14">}</span><span class="ͼ19">)</span>
# <span class="ͼs">and</span>
# bs<span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'div'</span><span class="ͼ19">,</span>
# <span class="ͼ14">{</span><span class="ͼ12">'class'</span>:
# <span class="ͼ12">'MPProductSlider-Main
# relative'</span><span class="ͼ14">}</span><span class="ͼ19">)</span><span class="ͼ19">.</span><span class="ͼz">find</span><span class="ͼ19">(</span><span class="ͼ12">'img'</span><span class="ͼ19">)</span>
# <span class="ͼs">else</span>
# <span class="ͼs">None</span><span class="ͼ19">)</span>
#
#
#
#     100%|████████████████████████████████████████████████████████████████████████████████| 249/249 [02:47<00:00,  1.48it/s]
#
# \[126\]:
#
# df <span class="ͼ10">=</span>
# pd<span class="ͼ19">.</span><span class="ͼz">DataFrame</span><span class="ͼ19">(</span>
#
# zip<span class="ͼ19">(</span>Title<span class="ͼ19">,</span>
# Rating<span class="ͼ19">,</span> Comment<span class="ͼ19">,</span>
# Product_Code<span class="ͼ19">,</span> Price<span class="ͼ19">,</span>
# Seller<span class="ͼ19">,</span>
# Image<span class="ͼ19">)</span><span class="ͼ19">,</span>
#
# columns<span class="ͼ10">=</span><span class="ͼ14">\[</span><span class="ͼ12">'Title'</span><span class="ͼ19">,</span>
# <span class="ͼ12">'Rating'</span><span class="ͼ19">,</span>
# <span class="ͼ12">'Comment'</span><span class="ͼ19">,</span>
# <span class="ͼ12">'Product_Code'</span><span class="ͼ19">,</span>
# <span class="ͼ12">'Product_Price'</span><span class="ͼ19">,</span>
# <span class="ͼ12">'Seller'</span><span class="ͼ19">,</span>
# <span class="ͼ12">'Product_info'</span><span class="ͼ14">\]</span>
#
# <span class="ͼ19">)</span>
#
#
#
# df<span class="ͼ19">.</span><span class="ͼz">to_excel</span><span class="ͼ19">(</span><span class="ͼ12">'Umico_data_part.xlsx'</span><span class="ͼ19">,</span>
# index<span class="ͼ10">=</span><span class="ͼ1d">False</span><span class="ͼ19">)</span>
#
#
#
# \[160\]:
#
# df<span class="ͼ14">\[</span><span class="ͼ12">'Title'</span><span class="ͼ14">\]</span>
# <span class="ͼ10">=</span>
# df<span class="ͼ14">\[</span><span class="ͼ12">'Title'</span><span class="ͼ14">\]</span><span class="ͼ19">.</span><span class="ͼz">str</span><span class="ͼ19">.</span><span class="ͼz">replace</span><span class="ͼ19">(</span><span class="ͼ12">'\n'</span><span class="ͼ19">,</span>
# <span class="ͼ12">''</span><span class="ͼ19">,</span>
# regex<span class="ͼ10">=</span><span class="ͼ1d">True</span><span class="ͼ19">)</span>
#
# df<span class="ͼ14">\[</span><span class="ͼ12">'Product_Code'</span><span class="ͼ14">\]</span>
# <span class="ͼ10">=</span>
# df<span class="ͼ14">\[</span><span class="ͼ12">'Product_Code'</span><span class="ͼ14">\]</span><span class="ͼ19">.</span><span class="ͼz">str</span><span class="ͼ19">.</span><span class="ͼz">replace</span><span class="ͼ19">(</span><span class="ͼ12">'Məhsulun
# kodu:'</span><span class="ͼ19">,</span>
# <span class="ͼ12">''</span><span class="ͼ19">,</span>
# regex<span class="ͼ10">=</span><span class="ͼ1d">True</span><span class="ͼ19">)</span>
#
# <span class="ͼ11">\# df\['Product_Price'\] =
# df\['Product_Price'\].str.replace('\n', '',regex=True)</span>
#
# df<span class="ͼ14">\[</span><span class="ͼ12">'Seller'</span><span class="ͼ14">\]</span>
# <span class="ͼ10">=</span>
# df<span class="ͼ14">\[</span><span class="ͼ12">'Seller'</span><span class="ͼ14">\]</span><span class="ͼ19">.</span><span class="ͼz">str</span><span class="ͼ19">.</span><span class="ͼz">replace</span><span class="ͼ19">(</span><span class="ͼ12">'\n'</span><span class="ͼ19">,</span>
# <span class="ͼ12">''</span><span class="ͼ19">,</span>
# regex<span class="ͼ10">=</span><span class="ͼ1d">True</span><span class="ͼ19">)</span>
#
# df<span class="ͼ14">\[</span><span class="ͼ12">'Comment'</span><span class="ͼ14">\]</span>
# <span class="ͼ10">=</span>
# df<span class="ͼ14">\[</span><span class="ͼ12">'Comment'</span><span class="ͼ14">\]</span><span class="ͼ19">.</span><span class="ͼz">str</span><span class="ͼ19">.</span><span class="ͼz">replace</span><span class="ͼ19">(</span><span class="ͼ12">'Rəy
# yoxdur'</span><span class="ͼ19">,</span>
# <span class="ͼ12">''</span><span class="ͼ19">,</span>
# regex<span class="ͼ10">=</span><span class="ͼ1d">True</span><span class="ͼ19">)</span>
#
# df<span class="ͼ14">\[</span><span class="ͼ12">'Real_Price'</span><span class="ͼ14">\]</span>
# <span class="ͼ10">=</span>
# df<span class="ͼ14">\[</span><span class="ͼ12">'Real_Price'</span><span class="ͼ14">\]</span><span class="ͼ19">.</span><span class="ͼz">str</span><span class="ͼ19">.</span><span class="ͼz">replace</span><span class="ͼ19">(</span><span class="ͼ12">'₼'</span><span class="ͼ19">,</span>
# <span class="ͼ12">''</span><span class="ͼ19">,</span>
# regex<span class="ͼ10">=</span><span class="ͼ1d">True</span><span class="ͼ19">)</span>
#
# df<span class="ͼ14">\[</span><span class="ͼ12">'Promo_Price'</span><span class="ͼ14">\]</span>
# <span class="ͼ10">=</span>
# df<span class="ͼ14">\[</span><span class="ͼ12">'Promo_Price'</span><span class="ͼ14">\]</span><span class="ͼ19">.</span><span class="ͼz">str</span><span class="ͼ19">.</span><span class="ͼz">replace</span><span class="ͼ19">(</span><span class="ͼ12">'Kampaniyanın
# bitmə
# müddəti:'</span><span class="ͼ19">,</span><span class="ͼ12">''</span><span class="ͼ19">,</span>
# regex<span class="ͼ10">=</span><span class="ͼ1d">True</span><span class="ͼ19">)</span>
#
# \[130\]:
#
# Promo_qiymet <span class="ͼ10">=</span>
# list<span class="ͼ19">(</span><span class="ͼ19">)</span>
#
# Real_qiymet <span class="ͼ10">=</span>
# list<span class="ͼ19">(</span><span class="ͼ19">)</span>
#
#
#
# <span class="ͼs">for</span> val <span class="ͼs">in</span>
# df<span class="ͼ14">\[</span><span class="ͼ12">'Product_Price'</span><span class="ͼ14">\]</span>:
#
# <span class="ͼs">if</span>
# val<span class="ͼ19">.</span><span class="ͼz">count</span><span class="ͼ19">(</span><span class="ͼ12">'₼'</span><span class="ͼ19">)</span>
# <span class="ͼ10">==</span> <span class="ͼu">2</span>:
#
# Promo_qiymet<span class="ͼ19">.</span><span class="ͼz">append</span><span class="ͼ19">(</span>val<span class="ͼ19">.</span><span class="ͼz">split</span><span class="ͼ19">(</span><span class="ͼ12">'₼'</span><span class="ͼ19">)</span><span class="ͼ14">\[</span><span class="ͼu">0</span><span class="ͼ14">\]</span><span class="ͼ19">)</span>
#
# Real_qiymet<span class="ͼ19">.</span><span class="ͼz">append</span><span class="ͼ19">(</span>val<span class="ͼ19">.</span><span class="ͼz">split</span><span class="ͼ19">(</span><span class="ͼ12">'₼'</span><span class="ͼ19">)</span><span class="ͼ14">\[</span><span class="ͼu">1</span><span class="ͼ14">\]</span><span class="ͼ19">)</span>
#
# print <span class="ͼ19">(</span>val<span class="ͼ19">)</span>
#
# <span class="ͼs">else</span>:
#
# Promo_qiymet<span class="ͼ19">.</span><span class="ͼz">append</span>
# <span class="ͼ19">(</span><span class="ͼs">None</span><span class="ͼ19">)</span>
#
# Real_qiymet<span class="ͼ19">.</span><span class="ͼz">append</span><span class="ͼ19">(</span>val<span class="ͼ19">)</span>
#
# df<span class="ͼ14">\[</span><span class="ͼ12">'Real_Price'</span><span class="ͼ14">\]</span>
# <span class="ͼ10">=</span> Real_qiymet
#
# df<span class="ͼ14">\[</span><span class="ͼ12">'Promo_Price'</span><span class="ͼ14">\]</span>
# <span class="ͼ10">=</span> Promo_qiymet
#
#           81.37 ₼            86.90 ₼
#           1.65 ₼            1.76 ₼
#           1.03 ₼            1.10 ₼
#           3.91 ₼            4.18 ₼
#           81.37 ₼            86.90 ₼
#           5.56 ₼            5.94 ₼
#           1.65 ₼            1.76 ₼
#           1.24 ₼            1.32 ₼
#           3.91 ₼            4.18 ₼
#     Kampaniyanın bitmə müddəti:         66.53 ₼            127.95 ₼
#           1.24 ₼            1.32 ₼
#           1.65 ₼            1.76 ₼
#           4.02 ₼            4.29 ₼
#           3.91 ₼            4.18 ₼
#           1.03 ₼            1.10 ₼
#     Kampaniyanın bitmə müddəti:         36.61 ₼            70.40 ₼
#           4.64 ₼            4.95 ₼
#           1.85 ₼            1.98 ₼
#           1.24 ₼            1.32 ₼
#           3.91 ₼            4.18 ₼
#           1.03 ₼            1.10 ₼
#           81.37 ₼            86.90 ₼
#           4.64 ₼            4.95 ₼
#           3.19 ₼            3.41 ₼
#           2.58 ₼            2.75 ₼
#           3.91 ₼            4.18 ₼
#           1.03 ₼            1.10 ₼
#     Kampaniyanın bitmə müddəti:         66.53 ₼            127.95 ₼
#           4.64 ₼            4.95 ₼
#           2.47 ₼            2.64 ₼
#           1.96 ₼            2.09 ₼
#           1.03 ₼            1.10 ₼
#           3.91 ₼            4.18 ₼
#           28.63 ₼            30.58 ₼
#           11.54 ₼            12.32 ₼
#           1.85 ₼            1.98 ₼
#           1.65 ₼            1.76 ₼
#           3.91 ₼            4.18 ₼
#           1.03 ₼            1.10 ₼
#           25.44 ₼            27.17 ₼
#           2.47 ₼            2.64 ₼
#           1.85 ₼            1.98 ₼
#           1.03 ₼            1.10 ₼
#           1.03 ₼            1.10 ₼
#           112.27 ₼            119.90 ₼
#           4.64 ₼            4.95 ₼
#           2.58 ₼            2.75 ₼
#           1.03 ₼            1.10 ₼
#           20.50 ₼            21.89 ₼
#           4.64 ₼            4.95 ₼
#           1.65 ₼            1.76 ₼
#           69.01 ₼            73.70 ₼
#           1.75 ₼            1.87 ₼
#           1.96 ₼            2.09 ₼
#           2.88 ₼            3.08 ₼
#           69.01 ₼            73.70 ₼
#           3.50 ₼            7.00 ₼
#           1.75 ₼            1.87 ₼
#           36.26 ₼            38.72 ₼
#           1.24 ₼            1.32 ₼
#           1.65 ₼            1.76 ₼
#           35.02 ₼            37.40 ₼
#           5.56 ₼            5.94 ₼
#           1.65 ₼            1.76 ₼
#           2.47 ₼            2.64 ₼
#           33.78 ₼            36.08 ₼
#           5.56 ₼            5.94 ₼
#           1.65 ₼            1.76 ₼
#           28.12 ₼            30.03 ₼
#           13.50 ₼            22.50 ₼
#           2.58 ₼            2.75 ₼
#           21.73 ₼            23.21 ₼
#           11.54 ₼            12.32 ₼
#           3.50 ₼            7.00 ₼
#           9.48 ₼            10.12 ₼
#           1.85 ₼            1.98 ₼
#           14.82 ₼            24.70 ₼
#           2.58 ₼            2.75 ₼
#           19.06 ₼            20.35 ₼
#           2.88 ₼            3.08 ₼
#           11.54 ₼            12.32 ₼
#           1.85 ₼            1.98 ₼
#           25.44 ₼            27.17 ₼
#           1.75 ₼            1.87 ₼
#           13.50 ₼            22.50 ₼
#           1.85 ₼            1.98 ₼
#           1.55 ₼            1.65 ₼
#           1.85 ₼            1.98 ₼
#           29.77 ₼            31.79 ₼
#           1.24 ₼            1.32 ₼
#           1.85 ₼            1.98 ₼
#           112.27 ₼            119.90 ₼
#           4.02 ₼            4.29 ₼
#           2.99 ₼            3.19 ₼
#           30.59 ₼            32.67 ₼
#           4.02 ₼            4.29 ₼
#           1.24 ₼            1.32 ₼
#     Kampaniyanın bitmə müddəti:         66.53 ₼            127.95 ₼
#           1.85 ₼            1.98 ₼
#           13.50 ₼            22.50 ₼
#           1.85 ₼            1.98 ₼
#           27.71 ₼            29.59 ₼
#           1.55 ₼            1.65 ₼
#           6.80 ₼            7.26 ₼
#           3.50 ₼            7.00 ₼
#           22.97 ₼            24.53 ₼
#           8.03 ₼            8.58 ₼
#           6.80 ₼            7.26 ₼
#           1.96 ₼            2.09 ₼
#           43.16 ₼            46.09 ₼
#           8.03 ₼            8.58 ₼
#           6.39 ₼            6.82 ₼
#           1.85 ₼            1.98 ₼
#     Kampaniyanın bitmə müddəti:         36.61 ₼            70.40 ₼
#           9.79 ₼            10.45 ₼
#           6.39 ₼            6.82 ₼
#           1.85 ₼            1.98 ₼
#           27.30 ₼            29.15 ₼
#           5.56 ₼            5.94 ₼
#           3.50 ₼            7.00 ₼
#           69.01 ₼            73.70 ₼
#           4.64 ₼            4.95 ₼
#           3.50 ₼            7.00 ₼
#     Kampaniyanın bitmə müddəti:         66.53 ₼            127.95 ₼
#           3.85 ₼            7.70 ₼
#           112.27 ₼            119.90 ₼
#           13.50 ₼            22.50 ₼
#           3.50 ₼            7.00 ₼
#           17.82 ₼            19.03 ₼
#           2.47 ₼            2.64 ₼
#           3.50 ₼            7.00 ₼
#           5.15 ₼            5.50 ₼
#           5.99 ₼            14.00 ₼
#           2.88 ₼            3.08 ₼
#           4.64 ₼            4.95 ₼
#           2.99 ₼            4.99 ₼
#           1.55 ₼            1.65 ₼
#           1.96 ₼            2.09 ₼
#           13.50 ₼            22.50 ₼
#           3.61 ₼            3.85 ₼
#           1.85 ₼            1.98 ₼
#           1.85 ₼            1.98 ₼
#           1.96 ₼            2.09 ₼
#           7.21 ₼            7.70 ₼
#           1.85 ₼            1.98 ₼
#           1.96 ₼            2.09 ₼
#           14.82 ₼            24.70 ₼
#           9.79 ₼            10.45 ₼
#           1.85 ₼            1.98 ₼
#           6.80 ₼            7.26 ₼
#           8.45 ₼            9.02 ₼
#           1.85 ₼            1.98 ₼
#           6.80 ₼            7.26 ₼
#           9.79 ₼            10.45 ₼
#           9.79 ₼            10.45 ₼
#           1.85 ₼            1.98 ₼
#           6.80 ₼            7.26 ₼
#           1.24 ₼            1.32 ₼
#           1.85 ₼            1.98 ₼
#           6.80 ₼            7.26 ₼
#           8.45 ₼            9.02 ₼
#           1.65 ₼            1.76 ₼
#           6.39 ₼            6.82 ₼
#           1.65 ₼            1.76 ₼
#           1.65 ₼            1.76 ₼
#           1.55 ₼            1.65 ₼
#           8.45 ₼            9.02 ₼
#           1.75 ₼            1.87 ₼
#           3.50 ₼            7.00 ₼
#           6.80 ₼            7.26 ₼
#           2.99 ₼            4.99 ₼
#           7.62 ₼            8.14 ₼
#           6.39 ₼            6.82 ₼
#           1.85 ₼            1.98 ₼
#           1.24 ₼            1.32 ₼
#           5.67 ₼            6.05 ₼
#           1.24 ₼            1.32 ₼
#           2.99 ₼            4.99 ₼
#           5.67 ₼            6.05 ₼
#           2.99 ₼            4.99 ₼
#           6.80 ₼            7.26 ₼
#           2.99 ₼            4.99 ₼
#           2.99 ₼            4.99 ₼
#           2.99 ₼            4.99 ₼
#           2.99 ₼            4.99 ₼
#           2.99 ₼            4.99 ₼
#           2.99 ₼            4.99 ₼
#           2.88 ₼            3.08 ₼
#           2.99 ₼            4.99 ₼
#           2.99 ₼            4.99 ₼
#           2.99 ₼            4.99 ₼
#           2.88 ₼            3.08 ₼
#           1.65 ₼            1.76 ₼
#           2.99 ₼            4.99 ₼
#           1.96 ₼            2.09 ₼
#           2.88 ₼            3.08 ₼
#           2.88 ₼            3.08 ₼
#           2.58 ₼            2.75 ₼
#           2.99 ₼            4.99 ₼
#           2.88 ₼            3.08 ₼
#           1.96 ₼            2.09 ₼
#           1.65 ₼            1.76 ₼
#           2.88 ₼            3.08 ₼
#           1.65 ₼            1.76 ₼
#           2.88 ₼            3.08 ₼
#           2.88 ₼            3.08 ₼
#           1.96 ₼            2.09 ₼
#           1.65 ₼            1.76 ₼
#           2.88 ₼            3.08 ₼
#           11.25 ₼            22.50 ₼
#           2.88 ₼            3.08 ₼
#           7.35 ₼            11.30 ₼
#           4.02 ₼            4.29 ₼
#           10.13 ₼            22.50 ₼
#           1.65 ₼            1.76 ₼
#           4.02 ₼            4.29 ₼
#           11.25 ₼            22.50 ₼
#           6.39 ₼            6.82 ₼
#
# \[132\]:
#
# df<span class="ͼ19">.</span><span class="ͼz">drop</span><span class="ͼ19">(</span><span class="ͼ12">'Product_Price'</span><span class="ͼ19">,</span>
# axis <span class="ͼ10">=</span>
# <span class="ͼu">1</span><span class="ͼ19">,</span> inplace
# <span class="ͼ10">=</span>
# <span class="ͼ1d">True</span><span class="ͼ19">)</span>
#
# \[315\]:
#
# df <span class="ͼ10">=</span>
# df<span class="ͼ14">\[</span><span class="ͼ14">\[</span><span class="ͼ12">'Title'</span><span class="ͼ19">,</span><span class="ͼ12">'Miqdar'</span><span class="ͼ19">,</span><span class="ͼ12">'Real_Price'</span><span class="ͼ19">,</span>
# <span class="ͼ12">'Promo_Price'</span><span class="ͼ19">,</span><span class="ͼ12">'Promo_Percent'</span><span class="ͼ19">,</span>
# <span class="ͼ12">'Rating'</span><span class="ͼ19">,</span>
# <span class="ͼ12">'Comment'</span><span class="ͼ19">,</span>
# <span class="ͼ12">'Product_Code'</span><span class="ͼ19">,</span>
# <span class="ͼ12">'Seller'</span><span class="ͼ19">,</span>
# <span class="ͼ12">'Product_info'</span><span class="ͼ14">\]</span><span class="ͼ14">\]</span>
#
# \[176\]:
#
# df<span class="ͼ14">\[</span><span class="ͼ12">'Promo_Price'</span><span class="ͼ14">\]</span><span class="ͼ10">=</span>df<span class="ͼ14">\[</span><span class="ͼ12">'Promo_Price'</span><span class="ͼ14">\]</span><span class="ͼ19">.</span><span class="ͼz">astype</span><span class="ͼ19">(</span>float<span class="ͼ19">)</span>
#
# df<span class="ͼ14">\[</span><span class="ͼ12">'Real_Price'</span><span class="ͼ14">\]</span><span class="ͼ10">=</span>df<span class="ͼ14">\[</span><span class="ͼ12">'Real_Price'</span><span class="ͼ14">\]</span><span class="ͼ19">.</span><span class="ͼz">astype</span><span class="ͼ19">(</span>float<span class="ͼ19">)</span>
#
# \[178\]:
#
# df<span class="ͼ14">\[</span><span class="ͼ12">'Promo_Percent'</span><span class="ͼ14">\]</span><span class="ͼ10">=</span><span class="ͼ19">(</span><span class="ͼu">1</span><span class="ͼ10">-</span>df<span class="ͼ14">\[</span><span class="ͼ12">'Promo_Price'</span><span class="ͼ14">\]</span>
# <span class="ͼ10">/</span>
# df<span class="ͼ14">\[</span><span class="ͼ12">'Real_Price'</span><span class="ͼ14">\]</span><span class="ͼ19">)</span><span class="ͼ19">.</span><span class="ͼz">round</span><span class="ͼ19">(</span><span class="ͼu">2</span><span class="ͼ19">)</span>
#
# \[180\]:
#
# df
#
# \[180\]:
#
# |  | Title | Real_Price | Promo_Price | Promo_Percent | Rating | Comment | Product_Code | Seller | Product_info |
# |----|----|----|----|----|----|----|----|----|----|
# | 0 | Quru südlü qatışıq Kendamil Organic 2, 6 a... | 86.90 | 81.37 | 0.06 | 0 |  | 805494 | Joker Baby Store ... | https://strgimgr.umico.az/sized/840/805494-dcb... |
# | 1 | Uşaqlar üçün peçenye Fleur Alpine, yulaflı... | 9.79 | NaN | NaN | 0 |  | 899912 | ROSSMANN Bu satı... | https://strgimgr.umico.az/sized/840/899912-8e2... |
# | 2 | Meyvəli püre ФрутоНяня Яблоко и Персик, 10... | 1.76 | 1.65 | 0.06 | 0 |  | 730119 | Joker Baby Store ... | https://strgimgr.umico.az/sized/840/730119-1e4... |
# | 3 | Multitaxıllı sıyıq Gerber, alma və moruq i... | 7.49 | NaN | NaN | 0 |  | 899917 | ROSSMANN Bu satı... | https://strgimgr.umico.az/sized/840/899917-ab6... |
# | 4 | Uşaq şirəsi ФрутоНяня alma, açıq rəngdə, 4... | 1.10 | 1.03 | 0.06 | 0 |  | 730265 | Joker Baby Store ... | https://strgimgr.umico.az/sized/840/730265-c65... |
# | ... | ... | ... | ... | ... | ... | ... | ... | ... | ... |
# | 244 | Meyvəli püre ФрутоНяня Яблоко и Банан, 100... | 1.76 | 1.65 | 0.06 | 2.5 |  | 730118 | Joker Baby Store ... | https://strgimgr.umico.az/sized/840/730118-11a... |
# | 245 | Uşaqlar üşün peçenye Когда я вырасту 5 зла... | 4.29 | 4.02 | 0.06 | 2.5 |  | 727522 | Joker Baby Store ... | https://strgimgr.umico.az/sized/840/727522-63a... |
# | 246 | Sıyıq Kabrita Qarabaşaq, keçi südündə, 4 a... | 22.50 | 11.25 | 0.50 | 2.3 | 2 rəy | 557850 | AllGoods Distributions ... | https://strgimgr.umico.az/sized/840/557850-ba0... |
# | 247 | Multitaxıl sıyıq Bebi südlü 7 taxıl, 6 ayd... | 6.82 | 6.39 | 0.06 | 2.5 |  | 824809 | Joker Baby Store ... | https://strgimgr.umico.az/sized/840/824809-46e... |
# | 248 | Multitaxıllı sıyıq Nestle Шагайка, alma/ar... | 6.19 | NaN | NaN | 0 |  | 899922 | ROSSMANN Bu satı... | https://strgimgr.umico.az/sized/840/899922-893... |
#
# 249 rows × 9 columns
#
# \[311\]:
#
# Miqdar <span class="ͼ10">=</span>
# list<span class="ͼ19">(</span><span class="ͼ19">)</span>
#
# <span class="ͼs">for</span> val <span class="ͼs">in</span>
# df<span class="ͼ14">\[</span><span class="ͼ12">'Title'</span><span class="ͼ14">\]</span><span class="ͼ19">.</span><span class="ͼz">values</span>:
#
# result <span class="ͼ10">=</span>
# re<span class="ͼ19">.</span><span class="ͼz">findall</span><span class="ͼ19">(</span><span class="ͼ12">r'\d\[\d\\\\\]\*\s\*(?:ml\|q\|kg\|l\|g\|kq)'</span><span class="ͼ19">,</span>
# val<span class="ͼ19">)</span>
#
# <span class="ͼs">if</span> result <span class="ͼ10">==</span>
# <span class="ͼ14">\[</span><span class="ͼ14">\]</span>:
#
# Miqdar<span class="ͼ19">.</span><span class="ͼz">append</span><span class="ͼ19">(</span><span class="ͼs">None</span><span class="ͼ19">)</span>
#
# <span class="ͼs">else</span>:
#
# Miqdar<span class="ͼ19">.</span><span class="ͼz">append</span><span class="ͼ19">(</span>result<span class="ͼ14">\[</span><span class="ͼu">0</span><span class="ͼ14">\]</span><span class="ͼ19">)</span>
#
# df<span class="ͼ14">\[</span><span class="ͼ12">'Miqdar'</span><span class="ͼ14">\]</span>
# <span class="ͼ10">=</span> Miqdar
#
# \[317\]:
#
# df
#
# \[317\]:
#
# |  | Title | Miqdar | Real_Price | Promo_Price | Promo_Percent | Rating | Comment | Product_Code | Seller | Product_info |
# |----|----|----|----|----|----|----|----|----|----|----|
# | 0 | Quru südlü qatışıq Kendamil Organic 2, 6 a... | 800 q | 86.90 | 81.37 | 0.06 | 0 |  | 805494 | Joker Baby Store ... | https://strgimgr.umico.az/sized/840/805494-dcb... |
# | 1 | Uşaqlar üçün peçenye Fleur Alpine, yulaflı... | 120 q | 9.79 | NaN | NaN | 0 |  | 899912 | ROSSMANN Bu satı... | https://strgimgr.umico.az/sized/840/899912-8e2... |
# | 2 | Meyvəli püre ФрутоНяня Яблоко и Персик, 10... | 100 q | 1.76 | 1.65 | 0.06 | 0 |  | 730119 | Joker Baby Store ... | https://strgimgr.umico.az/sized/840/730119-1e4... |
# | 3 | Multitaxıllı sıyıq Gerber, alma və moruq i... | 180 q | 7.49 | NaN | NaN | 0 |  | 899917 | ROSSMANN Bu satı... | https://strgimgr.umico.az/sized/840/899917-ab6... |
# | 4 | Uşaq şirəsi ФрутоНяня alma, açıq rəngdə, 4... | 0.2 l | 1.10 | 1.03 | 0.06 | 0 |  | 730265 | Joker Baby Store ... | https://strgimgr.umico.az/sized/840/730265-c65... |
# | ... | ... | ... | ... | ... | ... | ... | ... | ... | ... | ... |
# | 244 | Meyvəli püre ФрутоНяня Яблоко и Банан, 100... | 100 q | 1.76 | 1.65 | 0.06 | 2.5 |  | 730118 | Joker Baby Store ... | https://strgimgr.umico.az/sized/840/730118-11a... |
# | 245 | Uşaqlar üşün peçenye Когда я вырасту 5 зла... | 180 q | 4.29 | 4.02 | 0.06 | 2.5 |  | 727522 | Joker Baby Store ... | https://strgimgr.umico.az/sized/840/727522-63a... |
# | 246 | Sıyıq Kabrita Qarabaşaq, keçi südündə, 4 a... | 180 q | 22.50 | 11.25 | 0.50 | 2.3 | 2 rəy | 557850 | AllGoods Distributions ... | https://strgimgr.umico.az/sized/840/557850-ba0... |
# | 247 | Multitaxıl sıyıq Bebi südlü 7 taxıl, 6 ayd... | 200 q | 6.82 | 6.39 | 0.06 | 2.5 |  | 824809 | Joker Baby Store ... | https://strgimgr.umico.az/sized/840/824809-46e... |
# | 248 | Multitaxıllı sıyıq Nestle Шагайка, alma/ar... | 190 q | 6.19 | NaN | NaN | 0 |  | 899922 | ROSSMANN Bu satı... | https://strgimgr.umico.az/sized/840/899922-893... |
#
# 249 rows × 10 columns
#
# \[ \]:
#
#
#
# Click to add a cell.
